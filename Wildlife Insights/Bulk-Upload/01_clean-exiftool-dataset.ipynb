# %% [markdown]
# <a href="https://colab.research.google.com/github/FFI-Vietnam/camtrap-tools/blob/main/Wildlife%20Insights/bulk-upload/01_clean-exiftool-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
This script is used for cleaning the metadata spreadsheet generated by ExifTool
After runnning this script, 'data cleaning' folder is created

data cleaning
    |__ 1.1_clean_metadata_drop-column.csv
    |__ 1.2_clean_metadata_new-column.csv
    |__ 1.3_clean_metadata_single-species-row.csv
    |__ 1.4_clean_metadata_remove-blank.csv
    
"""

# %%
import pandas as pd
import numpy as np
import os

# %%
# mount with Google Drive to read and save file
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# specifies Colab directories and file names
root = '/content/drive/'

dataset_folder = 'My Drive/FFI/Wildlife Insights Bulk Upload Test/bulk-upload_template-autofill/dataset'
contain_folder = 'My Drive/FFI/Wildlife Insights Bulk Upload Test/bulk-upload_template-autofill/data cleaning'

metadata_dataset_file_name = 'image_metadata(2021-10-04).csv'
metadata_drop_column_file_name = "1.1_clean_metadata_drop-column.csv"
metadata_new_column_file_name = "1.2_clean_metadata_new-column.csv"
metadata_single_species_row_file_name = "1.3_clean_metadata_single-species-row.csv"
metadata_remove_blank_file_name = "1.4_clean_metadata_remove-no-animal-image.csv"

# %%
# useful functions
def read_csv_Google_drive(root, contain_folder, file_name):
  file_path = os.path.join(root, contain_folder, file_name)
  return pd.read_csv(file_path)

def save_csv_Google_drive(df, root, contain_folder, file_name):
  """
  function to save a csv file to Google Drive
  param examples:
    root = '/content/drive/'
    contain_folder = 'My Drive/FFI/dataset'
    file_name = 'image_metadata(2020-06-26)_full.csv'
  """
  # save file to Colab runtime storage (will be deleted when this notebook is closed)
  df.to_csv('dataframe.csv', index=False)

  # save file back to Google Drive for permanent storage
  folder_path = os.path.join(root, contain_folder)
  file_path = os.path.join(root, contain_folder, file_name)
  try:
    os.makedirs(folder_path)
  except:
    pass

  with open('dataframe.csv', 'r') as f:
    df_file = f.read()

  with open(file_path, 'w') as f:
    f.write(df_file)

  print(f'File is saved to {file_name} in Google Drive at {file_path}')

# %%
# read full dataset
df = read_csv_Google_drive(root, dataset_folder, metadata_dataset_file_name)
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2822: DtypeWarning: Columns (10,15,21,42,43,46,57,58,59,61,62,76) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
#                                           SourceFile  ...  YResolution
# 0  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...          1.0
# 1  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...          1.0
# 2  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...          1.0
# 3  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...          1.0
# 4  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...          1.0
#
# [5 rows x 80 columns]

# %%
# 00) sanity check num files
# read full dataset
df = read_csv_Google_drive(root, dataset_folder, metadata_dataset_file_name)

# !ls -R "/content/drive/My Drive/FFI/Kon Plong/2019-2020 Survey/Processed images/Final" > drive_files.txt
with open("drive_files.txt") as f:
  drive_files = f.read().split('\n')

all_files_on_drive = []
for f in drive_files:
  if f.lower().endswith(('jpg', 'jpeg')):
    all_files_on_drive.append(f)

all_files_in_metadata = df['FileName'].to_list()

diff_1 = list(set(all_files_on_drive) - set(all_files_in_metadata))
diff_2 = list(set(all_files_in_metadata) - set(all_files_on_drive))

with open('on_Drive_but_not_metadata.txt', 'w') as f:
  for i in diff_1:
    f.write(i+'\n')

with open('in_metadata_but_not_Drive.txt', 'w') as f:
  for i in diff_2:
    f.write(i+'\n')    

print("There are", len(set(diff_1)), "files on Drive but not in metadata")
print("Check on_Drive_but_not_metadata.txt (just created) for more details")
print()
print("There are", len(set(diff_2)), "files in metadata but not on Drive")
print("Check in_metadata_but_not_Drive.txt (just created) for more details")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2822: DtypeWarning: Columns (10,15,21,42,43,46,57,58,59,61,62,76) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# There are 0 files on Drive but not in metadata
# Check on_Drive_but_not_metadata.txt (just created) for more details
#
# There are 0 files in metadata but not on Drive
# Check in_metadata_but_not_Drive.txt (just created) for more details

# %%
# 01) keep important columns
df = read_csv_Google_drive(root, dataset_folder, metadata_dataset_file_name)

df = df[['SourceFile', 'Directory', 'FileName', 'DateTimeOriginal', 'CatalogSets', 'Make', 'Model', 'Flash']]

# save to metadata.csv in Google Drive
save_csv_Google_drive(df, root, contain_folder, metadata_drop_column_file_name)

df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2822: DtypeWarning: Columns (10,15,21,42,43,46,57,58,59,61,62,76) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# File is saved to 1.1_clean_metadata_drop-column.csv in Google Drive at /content/drive/My Drive/FFI/Wildlife Insights Bulk Upload Test/bulk-upload_template-autofill/data cleaning/1.1_clean_metadata_drop-column.csv
#                                           SourceFile  ...     Flash
# 0  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...  No Flash
# 1  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...  No Flash
# 2  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...  No Flash
# 3  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...  No Flash
# 4  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...  No Flash
#
# [5 rows x 8 columns]

# %%
# check if cameras folder match with Make column
df = read_csv_Google_drive(root, contain_folder, metadata_drop_column_file_name)

count = 0
wrong = []

for i in range(len(df)):
  folder_name = df['Directory'].iat[i].split('/')[-1]
  if ('CAM' + folder_name) != df['Model'].iat[i]:
    wrong.append(df['FileName'].iat[i])

df = df[df['FileName'].isin(wrong)]
df = df[['Directory', 'FileName', 'Make', 'Model']]

df
# save_csv_Google_drive(df, root, contain_folder, 'wrong_folder.csv')
# Out:
#                                                Directory  ... Model
# 52480  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52481  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52485  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52486  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52487  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52494  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52495  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52496  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52500  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52501  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52502  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52503  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52504  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52505  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52515  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52516  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52517  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52518  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52519  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
# 52520  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...   NaN
#
# [20 rows x 4 columns]

# %%
# 02) create new columns
"""
- certainty: an id is certain or not, follow WI guideline. Values = ['Absolutely sure', 'Not  sure']
- species_common_name: extract from tag 'Species' in 'CatalogSets'.
- observer: extract from tag 'Observer' in 'CatalogSets'.
- uploaded: specify if this image has already been uploaded to WI ('x' means YES, empty means NO)
- station: the station of the camera
- camera_id: the camera that took this image
- datetime_created: date and time the image was captured. Format: YYYY-MM-DD hh:mm:ss
"""
df = read_csv_Google_drive(root, contain_folder, metadata_drop_column_file_name)

certainty = [] 
species_common_name = [] 
observer = []
people = []
uploaded = []
station = []
camera_id = []
datetime_created = []

UNCERTAIN = 'Uncertain Identification'
SPECIES_PREFIX = 'Species'
OBSERVER_PREFIX = 'Observer'
PEOPLE_PREFIX = 'People'

# create certainty, species_common_name, observer, and people columns
catalog_sets = df['CatalogSets']
for i in range(len(catalog_sets)):
  # split the tags
  if catalog_sets[i] is not np.NaN:
    # specify the image is not uploaded
    uploaded.append('')
    catalog = str(catalog_sets[i]).split(', ')
    # specify uncertainty
    if UNCERTAIN in catalog:
      certainty.append('Not sure')
    else:
      certainty.append('Absolutely sure')
    spe = '' # for species
    obs = '' # for observer
    for i in range(len(catalog)): # go through each tag
      if SPECIES_PREFIX in catalog[i]:
        if catalog[i].split('|')[1] != 'Human':
          if '(unknown)' in catalog[i].split('|')[1]:
            # remove (unknown) mark
            spe = spe + ', ' + catalog[i].split('|')[1].split('(unknown)')[0]
          else:
            spe = spe + ', ' + catalog[i].split('|')[1]
      # Human is a bit tricky, it either has 'People' or 'Human' prefix, or both, 
      # so have to check to avoid duplication
      if PEOPLE_PREFIX in catalog[i]:
        if not 'Human' in spe:
          spe = spe + ', ' + 'Human'
      # specify observer
      if OBSERVER_PREFIX in catalog[i]:
        obs = obs + ', ' + catalog[i].split('|')[1]

    species_common_name.append(spe[2:]) # eliminate leading ', '
    observer.append(obs[2:])

  else:
    uploaded.append('')
    certainty.append('')
    observer.append('')
    species_common_name.append('')

# create station and camera_id column
for file in df['SourceFile'].to_list():
  station.append(file.split('/')[-3])
  camera_id.append(file.split('/')[-2])

# create datatime created column in format YYYY-MM-DD hh:mm:ss
for dt in df['DateTimeOriginal'].to_list():
  try:
    YYYY, MM, DD = dt.split()[0].split(':')
    hh, mm, ss = dt.split()[1].split(':')
    # pad leading 0
    MM, DD, hh, mm, ss = MM.zfill(2), DD.zfill(2), hh.zfill(2), mm.zfill(2), ss.zfill(2)
    datetime_format = f'{YYYY}-{MM}-{DD} {hh}:{mm}:{ss}'
    datetime_created.append(datetime_format)
  except:
    # in case null
    datetime_created.append('')

df['datetime_created'] = datetime_created
df['certainty'] = certainty
df['species_common_name'] = species_common_name
df['observer'] = observer
df['uploaded_to_WI'] = uploaded
df['station'] = station
df['camera_id'] = camera_id

# save file to 02_metadata_new-column.csv in Google Drive
save_csv_Google_drive(df, root, contain_folder, metadata_new_column_file_name)

df.head(5)
# Out:
# File is saved to 1.2_clean_metadata_new-column.csv in Google Drive at /content/drive/My Drive/FFI/Wildlife Insights Bulk Upload Test/bulk-upload_template-autofill/data cleaning/1.2_clean_metadata_new-column.csv
#                                           SourceFile  ... camera_id
# 0  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...     68974
# 1  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...     68974
# 2  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...     68974
# 3  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...     68974
# 4  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...     68974
#
# [5 rows x 15 columns]

# %%
# 03) explode species_common_name column so that each row contains at most one 
# species, i.e. if one image has more than one species, it will be exploded into
# multiple rows

df = read_csv_Google_drive(root, contain_folder, metadata_new_column_file_name)

# set the columns not to be touched as the index
col = df.columns.to_list()
col.remove('species_common_name')

# split on comma to get a column of lists, then call explode to explode the 
# list values into their own rows, then reset the index
df = df.set_index(col).apply(lambda x: x.str.split(',').explode()).reset_index()

# strip ' ' at both ends
df['species_common_name'] = df['species_common_name'].str.strip()

# save file to 03_metadata_single-species-row.csv in Google Drive
save_csv_Google_drive(df, root, contain_folder, metadata_single_species_row_file_name)

df.sample(5)
# Out:
# File is saved to 1.3_clean_metadata_single-species-row.csv in Google Drive at /content/drive/My Drive/FFI/Wildlife Insights Bulk Upload Test/bulk-upload_template-autofill/data cleaning/1.3_clean_metadata_single-species-row.csv
#                                               SourceFile  ... species_common_name
# 50643  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...               Human
# 15660  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...                 NaN
# 49903  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...                 NaN
# 71023  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...               Human
# 90489  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...                 NaN
#
# [5 rows x 15 columns]

# %%
# 04) remove non-animal images

df = read_csv_Google_drive(root, contain_folder, metadata_single_species_row_file_name)

df['species_common_name'].replace('', np.nan, inplace=True)
df.dropna(subset=['species_common_name'], how = 'all', inplace=True)

# save file to 04_metadata_remove-blank.csv in Google Drive
save_csv_Google_drive(df, root, contain_folder, metadata_remove_blank_file_name)

df.head(5)
# Out:
# File is saved to 1.4_clean_metadata_remove-no-animal-image.csv in Google Drive at /content/drive/My Drive/FFI/Wildlife Insights Bulk Upload Test/bulk-upload_template-autofill/data cleaning/1.4_clean_metadata_remove-no-animal-image.csv
#                                           SourceFile  ... species_common_name
# 0  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...               Human
# 1  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...               Human
# 2  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...               Human
# 3  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...               Human
# 4  H:/My Drive/Camera Trap Data/Kon Plong/2019-20...  ...               Human
#
# [5 rows x 15 columns]
